# %% [markdown]
# ### Build a customer service multi-agent system : It will take a customer's query and there will be two agents which will be responding to that. So basically there will be one first level and there will be one second level agent.  So what should happen when I kick off my crew basically,  one response should be prepared from my first agent and that should be reviewed for quality and then a final response should be prepared

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# %%
#!pip install crewai==0.28.8 crewai_tools==0.1.6 langchain_community==0.0.29

# %%
# Load the .env file from local
import openai
from dotenv import load_dotenv
env_path = r'.env'
load_dotenv(env_path)
# Out:
# True

# %%
from crewai import Agent, Task, Crew

# %%
#Define first Agent(Level 1)
customer_assist_agent = Agent(
    role="Customer Care Specialist",
    goal="Deliver the most courteous and effective "
         "customer support on your team.",
    backstory=(
        "You are a valued team member at Crew AI (https://docs.crewai.com/introduction) "
        "and currently assigned to assist {customer}, a crucial client "
        "for the company."
        "Your mission is to ensure the highest quality of support!"
        "Provide detailed and thorough responses, "
        "avoiding any assumptions."
    ),
    allow_delegation=False,
    verbose=True
)

# %%
#Define second agent(Level 2)
quality_check_agent = Agent(
    role="Support Quality Analyst",
    goal="Be recognized for ensuring the highest "
         "standards of support quality in your team.",
    backstory=(
        "You are a key contributor at CrewAI (https://docs.crewai.com/introduction), "
        "working alongside your team to review a support request from {customer}. "
        "Your responsibility is to ensure that the Customer Care Specialist "
        "delivers top-notch service.\n"
        "It’s your duty to confirm that all responses are thorough, "
        "accurate, and free of assumptions."
    ),
    verbose=True
)

# %%
from crewai_tools import ScrapeWebsiteTool

# %%
docs_scrape_tool = ScrapeWebsiteTool(
    website_url="https://docs.crewai.com/introduction",config={}
)

# %%
customer_query_task = Task(
    description=(
        "{customer} has submitted a critical request:\n"
        "{inquiry}\n\n"
        "{person} from {customer} initiated the inquiry. "
        "Leverage all available resources and knowledge to "
        "deliver outstanding support."
        "Your goal is to provide a thorough and accurate resolution "
        "to the customer's question."
    ),
    expected_output=(
        "A comprehensive and well-researched response to the customer's inquiry "
        "that addresses every aspect of their concern.\n"
        "The response must reference all the tools and information sources used, "
        "including external materials or solutions. "
        "Ensure that the answer is exhaustive, leaves no room for follow-up questions, "
        "and maintains a professional, approachable tone."
    ),
    tools=[docs_scrape_tool],
    agent=customer_assist_agent,
)

# %%
response_review_task = Task(
    description=(
        "Evaluate the response prepared by the Customer Care Specialist for {customer}'s inquiry. "
        "Ensure the reply meets the highest standards of accuracy, completeness, and clarity "
        "expected in customer service.\n"
        "Confirm that every aspect of the customer's question has been addressed "
        "in a friendly and approachable manner.\n"
        "Verify the inclusion of appropriate references and sources used "
        "to gather the information, ensuring the response is well-supported and "
        "leaves no loose ends."
    ),
    expected_output=(
        "A polished, detailed, and ready-to-send response that completely addresses "
        "the customer's inquiry.\n"
        "The response should reflect all necessary feedback and adjustments while "
        "maintaining a relaxed yet professional tone that aligns with our cool and casual company culture."
    ),
    agent=quality_check_agent,
)

# %%
crewCSMAS = Crew(
  agents=[customer_assist_agent, quality_check_agent],
  tasks=[customer_query_task, response_review_task],
  verbose=True,
  memory=True
)

# %%
inputs = {
    "customer": "Unfold data science",
    "person": "Aman Kumar",
    "inquiry": "I need help with Crew AI "
               "and Understanding about Crew and Agent "
               "How to use Crew and Agent in CrewAI "
               "Can you provide guidance?"
}
result = crewCSMAS.kickoff(inputs=inputs)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 53b62ccf-fc0d-4f2c-8022-014d428d5e5d                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Unfold data science has submitted a critical request:                                                    │
# │  I need help with Crew AI and Understanding about Crew and Agent How to use Crew and Agent in CrewAI Can you    │
# │  provide guidance?                                                                                              │
# │                                                                                                                 │
# │  Aman Kumar from Unfold data science initiated the inquiry. Leverage all available resources and knowledge to   │
# │  deliver outstanding support.Your goal is to provide a thorough and accurate resolution to the customer's       │
# │  question.                                                                                                      │
# │  ID: 9986bbe7-22d3-4d0b-a7b0-748e3a1dcbd7                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Customer Care Specialist                                                                                │
# │                                                                                                                 │
# │  Task: Unfold data science has submitted a critical request:                                                    │
# │  I need help with Crew AI and Understanding about Crew and Agent How to use Crew and Agent in CrewAI Can you    │
# │  provide guidance?                                                                                              │
# │                                                                                                                 │
# │  Aman Kumar from Unfold data science initiated the inquiry. Leverage all available resources and knowledge to   │
# │  deliver outstanding support.Your goal is to provide a thorough and accurate resolution to the customer's       │
# │  question.                                                                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────── 🔧 Tool Execution Started (#1) ─────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool: read_website_content                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Tool read_website_content executed with result: The following text is scraped website content:
#
# Introduction - CrewAI Skip to main content CrewAI home page v1.14.4 English Search... ⌘ K Ask AI Start Cloud Trial crewAIInc/crewAI crewAIInc/crewAI Sea...
# ╭─────────────────────────────────────── ✅ Tool Execution Completed (#1) ────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool Completed                                                                                                 │
# │  Tool: read_website_content                                                                                     │
# │  Output: The following text is scraped website content:                                                         │
# │                                                                                                                 │
# │  Introduction - CrewAI Skip to main content CrewAI home page v1.14.4 English Search... ⌘ K Ask AI Start Cloud   │
# │  Trial crewAIInc/crewAI crewAIInc/crewAI Search... Navigation Get Started Introduction Home Documentation AMP   │
# │  API Reference Examples Changelog Website Forum Blog CrewGPT Get Started Introduction Build with AI Skills      │
# │  Installation Quickstart Guides Strategy Agents Crews Flows Tools Coding Tools Advanced Migration Core          │
# │  Concepts Agents Agent Capabilities Tasks Crews Flows Production Architecture Knowledge Skills LLMs Files       │
# │  Processes Collaboration Training Memory Reasoning Planning Testing CLI Tools Event Listeners Checkpointing     │
# │  MCP Integration MCP Servers as Tools in CrewAI MCP DSL Integration Stdio Transport SSE Transport Streamable    │
# │  HTTP Transport Connecting to Multiple MCP Servers MCP Security Considerations Tools Tools Overview File &      │
# │  Document Web Scraping & Browsing Search & Research Database & Data AI & Machine Learning Cloud & Storage       │
# │  Integrations Automation Observability CrewAI Tracing Overview Arize Phoenix Braintrust Datadog Integration     │
# │  Galileo LangDB Integration Langfuse Integration Langtrace Integration Maxim Integration MLflow Integration     │
# │  Neatlogs Integration OpenLIT Integration Opik Integration Patronus AI Evaluation Portkey Integration Weave     │
# │  Integration TrueFoundry Integration Learn Overview Strategic LLM Selection Guide Conditional Tasks Coding      │
# │  Agents Create Custom Tools Custom LLM Implementation Custom Manager Agent Customize Agents Image Generation    │
# │  with DALL-E Force Tool Output as Result Hierarchical Process Human Input on Execution Human-in-the-Loop        │
# │  (HITL) Workflows Human Feedback in Flows Kickoff Crew Asynchronously Kickoff Crew for Each Connect to any LLM  │
# │  Using CrewAI Without LiteLLM Using Multimodal Agents Replay Tasks from Latest Crew Kickoff Sequential          │
# │  Processes Using Annotations in crew.py Execution Hooks Overview LLM Call Hooks Tool Call Hooks Telemetry       │
# │  Telemetry Get Started Introduction Copy page Build AI agent teams that work together to tackle complex tasks   │
# │  Copy page Documentation Index Fetch the complete documentation index at: https://docs.crewai.com/llms.txt Use  │
# │  this file to discover all available pages before exploring further. ​ What is CrewAI?                           │
# │  CrewAI is the leading open-source framework for orchestrating autonomous AI agents and building complex        │
# │  workflows.                                                                                                     │
# │  It empowers developers to build production-ready multi-agent systems by combining the collaborative            │
# │  intelligence of Crews with the precise control of Flows .                                                      │
# │  CrewAI Flows : The backbone of your AI application. Flows allow you to create structured, event-driven         │
# │  workflows that manage state and control execution. They provide the scaffolding for your AI agents to work     │
# │  within.                                                                                                        │
# │  CrewAI Crews : The units of work within your Flow. Crews are teams of autonomous agents that collaborate to    │
# │  solve specific tasks delegated to them by the Flow.                                                            │
# │  With over 100,000 developers certified through our community courses, CrewAI is the standard for               │
# │  enterprise-ready AI automation.                                                                                │
# │  ​ Watch: Building CrewAI Agents & Flows with Coding Agent Skills                                                │
# │  Install our coding agent skills (Claude Code, Codex, …) to quickly get your coding agents up and running with  │
# │  CrewAI.                                                                                                        │
# │  You can install it with npx skills add crewaiinc/skills                                                        │
# │  ​ The CrewAI Architecture                                                                                       │
# │  CrewAI’s architecture is designed to balance autonomy with control.                                            │
# │  ​ 1. Flows: The Backbone                                                                                        │
# │  Think of a Flow as the “manager” or the “process definition” of your application. It defines the steps, the    │
# │  logic, and how data moves through your system.                                                                 │
# │  Flows provide:                                                                                                 │
# │  State Management : Persist data across steps and executions.                                                   │
# │  Event-Driven Execution : Trigger actions based on events or external inputs.                                   │
# │  Control Flow : Use conditional logic, loops, and branching.                                                    │
# │  ​ 2. Crews: The Intelligence                                                                                    │
# │  Crews are the “teams” that do the heavy lifting. Within a Flow, you can trigger a Crew to tackle a complex     │
# │  problem requiring creativity and collaboration.                                                                │
# │  Crews provide:                                                                                                 │
# │  Role-Playing Agents : Specialized agents with specific goals and tools.                                        │
# │  Autonomous Collaboration : Agents work together to solve tasks.                                                │
# │  Task Delegation : Tasks are assigned and executed based on agent capabilities.                                 │
# │  ​ How It All Works Together                                                                                     │
# │  The Flow triggers an event or starts a process.                                                                │
# │  The Flow manages the state and decides what to do next.                                                        │
# │  The Flow delegates a complex task to a Crew .                                                                  │
# │  The Crew ’s agents collaborate to complete the task.                                                           │
# │  The Crew returns the result to the Flow .                                                                      │
# │  The Flow continues execution based on the result.                                                              │
# │  ​ Key Features                                                                                                  │
# │  Production-Grade Flows Build reliable, stateful workflows that can handle long-running processes and complex   │
# │  logic. Autonomous Crews Deploy teams of agents that can plan, execute, and collaborate to achieve high-level   │
# │  goals. Flexible Tools Connect your agents to any API, database, or local tool. Enterprise Security Designed    │
# │  with security and compliance in mind for enterprise deployments.                                               │
# │  ​ When to Use Crews vs. Flows                                                                                   │
# │  The short answer: Use both.                                                                                    │
# │  For any production-ready application, start with a Flow .                                                      │
# │  Use a Flow to define the overall structure, state, and logic of your application.                              │
# │  Use a Crew within a Flow step when you need a team of agents to perform a specific, complex task that          │
# │  requires autonomy.                                                                                             │
# │  Use Case Architecture Simple Automation Single Flow with Python tasks Complex Research Flow managing state ->  │
# │  Crew performing research Application Backend Flow handling API requests -> Crew generating content -> Flow     │
# │  saving to DB                                                                                                   │
# │  ​ Why Choose CrewAI?                                                                                            │
# │  🧠 Autonomous Operation : Agents make intelligent decisions based on their roles and available tools           │
# │  📝 Natural Interaction : Agents communicate and collaborate like human team members                            │
# │  🛠️ Extensible Design : Easy to add new tools, roles, and capabilities                                          │
# │  🚀 Production Ready : Built for reliability and scalability in real-world applications                         │
# │  🔒 Security-Focused : Designed with enterprise security requirements in mind                                   │
# │  💰 Cost-Efficient : Optimized to minimize token usage and API calls                                            │
# │  ​ Ready to Start Building?                                                                                      │
# │  Build Your First Flow Learn how to create structured, event-driven workflows with precise control over         │
# │  execution. Build Your First Crew Step-by-step tutorial to create a collaborative AI team that works together   │
# │  to solve complex problems.                                                                                     │
# │  Install CrewAI Get started with CrewAI in your development environment. Quick Start Scaffold a Flow, run a     │
# │  crew with one agent, and generate a report end to end. Join the Community Connect with other developers, get   │
# │  help, and share your CrewAI experiences. Was this page helpful? Yes No Build with AI Next ⌘ I website x        │
# │  github linkedin youtube reddit Powered by This documentation is built and hosted on Mintlify, a developer      │
# │  documentation platform Assistant Responses are generated using AI and may contain mistakes.                    │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Customer Care Specialist                                                                                │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  CrewAI is an open-source framework designed to orchestrate autonomous AI agents and build complex workflows.   │
# │  It empowers developers to create production-ready multi-agent systems by combining the collaborative           │
# │  intelligence of Crews with the precise control of Flows.                                                       │
# │                                                                                                                 │
# │  Here is a detailed explanation of Crew and Agent in CrewAI and how to use them:                                │
# │                                                                                                                 │
# │  1. What is CrewAI?                                                                                             │
# │                                                                                                                 │
# │  CrewAI allows you to build AI applications where multiple agents work together to accomplish complex tasks.    │
# │  It offers components called Flows and Crews:                                                                   │
# │                                                                                                                 │
# │  - Flows: These are the backbone of your AI application. Flows allow you to create structured, event-driven     │
# │  workflows that manage state and control execution. They define steps, logic, and data movement through the     │
# │  system, providing state management, event-driven execution, and logic control with conditionals, loops, and    │
# │  branching.                                                                                                     │
# │                                                                                                                 │
# │  - Crews: These are teams of autonomous agents within a Flow. Crews are responsible for carrying out specific   │
# │  tasks delegated by the Flow. They operate collaboratively and autonomously, with agents having specialized     │
# │  roles and goals.                                                                                               │
# │                                                                                                                 │
# │  2. How Crews and Agents Work Together                                                                          │
# │                                                                                                                 │
# │  - The Flow triggers an event or starts a process.                                                              │
# │  - The Flow manages state and decides the next actions.                                                         │
# │  - The Flow delegates a complex task to a Crew.                                                                 │
# │  - The Crew’s agents collaborate and role-play specialized tasks to complete the assignment.                    │
# │  - The Crew returns the results to the Flow.                                                                    │
# │  - The Flow continues based on the results from the Crew.                                                       │
# │                                                                                                                 │
# │  3. Why Use Crews and Agents?                                                                                   │
# │                                                                                                                 │
# │  - Crews provide autonomous collaboration where agents communicate and work like team members, collectively     │
# │  solving complex problems.                                                                                      │
# │  - Agents are role-playing entities within the Crew with specific capabilities and tools tailored to fulfill    │
# │  parts of the task.                                                                                             │
# │  - Use Crews in a Flow when a complex, creative task needs multiple specialized agents collaborating to         │
# │  achieve high-level goals.                                                                                      │
# │  - Use Flows to manage the overall process, state, and logic, and Crews for intensive problem-solving steps     │
# │  inside that process.                                                                                           │
# │                                                                                                                 │
# │  4. Features and Benefits                                                                                       │
# │                                                                                                                 │
# │  - Production-grade Flows handle reliable, stateful workflows with complex logic.                               │
# │  - Autonomous Crews with teams of agents capable of intelligent decision-making and task execution.             │
# │  - Flexible integration with APIs, databases, and local tools.                                                  │
# │  - Designed for enterprise security, compliance, and scalability.                                               │
# │  - Designed to optimize cost by minimizing token usage and API calls.                                           │
# │                                                                                                                 │
# │  5. Getting Started                                                                                             │
# │                                                                                                                 │
# │  - Build your first Flow to create event-driven workflows.                                                      │
# │  - Create your first Crew as a collaborative AI team.                                                           │
# │  - Install CrewAI and add coding agent skills (e.g., Claude Code, Codex) to accelerate development.             │
# │  - Use Crew steps inside Flows for tasks requiring autonomous agent collaboration.                              │
# │                                                                                                                 │
# │  Summary: CrewAI builds AI applications by structuring workflows (Flows) and delegating complex tasks to teams  │
# │  of intelligent agents (Crews) within those workflows. The Flow manages the overall process and state, while    │
# │  Crews autonomously collaborate to solve tasks using their agent capabilities.                                  │
# │                                                                                                                 │
# │  If you need detailed tutorials or code examples, you can refer to CrewAI documentation for "Build Your First   │
# │  Flow" and "Build Your First Crew" guides and install the coding agent skills as described.                     │
# │                                                                                                                 │
# │  This explanation is based on CrewAI's official documentation available at                                      │
# │  https://docs.crewai.com/introduction.                                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Unfold data science has submitted a critical request:                                                    │
# │  I need help with Crew AI and Understanding about Crew and Agent How to use Crew and Agent in CrewAI Can you    │
# │  provide guidance?                                                                                              │
# │                                                                                                                 │
# │  Aman Kumar from Unfold data science initiated the inquiry. Leverage all available resources and knowledge to   │
# │  deliver outstanding support.Your goal is to provide a thorough and accurate resolution to the customer's       │
# │  question.                                                                                                      │
# │  Agent: Customer Care Specialist                                                                                │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Evaluate the response prepared by the Customer Care Specialist for Unfold data science's inquiry.        │
# │  Ensure the reply meets the highest standards of accuracy, completeness, and clarity expected in customer       │
# │  service.                                                                                                       │
# │  Confirm that every aspect of the customer's question has been addressed in a friendly and approachable         │
# │  manner.                                                                                                        │
# │  Verify the inclusion of appropriate references and sources used to gather the information, ensuring the        │
# │  response is well-supported and leaves no loose ends.                                                           │
# │  ID: d3cfbe55-f566-493e-bb25-b9a1c466b4a3                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Support Quality Analyst                                                                                 │
# │                                                                                                                 │
# │  Task: Evaluate the response prepared by the Customer Care Specialist for Unfold data science's inquiry.        │
# │  Ensure the reply meets the highest standards of accuracy, completeness, and clarity expected in customer       │
# │  service.                                                                                                       │
# │  Confirm that every aspect of the customer's question has been addressed in a friendly and approachable         │
# │  manner.                                                                                                        │
# │  Verify the inclusion of appropriate references and sources used to gather the information, ensuring the        │
# │  response is well-supported and leaves no loose ends.                                                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────── 🔧 Tool Execution Started (#1) ─────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool: search_memory                                                                                            │
# │  Args: {'queries': ['Customer Care Specialist response to Unfold data science CrewAI inquiry']}                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Tool search_memory executed with result: Found memories:
# - (score=0.86) Aman Kumar from Unfold Data Science initiated an inquiry about Crew AI and its functionalities.
#   categories: inquiries, technology, AI
#   entities: ['Aman Kumar', 'Unfol...
# ╭─────────────────────────────────────── ✅ Tool Execution Completed (#1) ────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool Completed                                                                                                 │
# │  Tool: search_memory                                                                                            │
# │  Output: Found memories:                                                                                        │
# │  - (score=0.86) Aman Kumar from Unfold Data Science initiated an inquiry about Crew AI and its                  │
# │  functionalities.                                                                                               │
# │    categories: inquiries, technology, AI                                                                        │
# │    entities: ['Aman Kumar', 'Unfold Data Science', 'Crew AI']                                                   │
# │    dates: []                                                                                                    │
# │    topics: ['inquiry', 'functionalities', 'AI technology']                                                      │
# │  - (score=0.82) Production-grade Flows in CrewAI handle reliable, stateful workflows with complex logic.        │
# │    categories: workflow, technology, CrewAI                                                                     │
# │    entities: []                                                                                                 │
# │    dates: []                                                                                                    │
# │    topics: ['stateful workflows', 'complex logic', 'CrewAI']                                                    │
# │  - (score=0.81) Users can refer to CrewAI documentation for detailed tutorials on building their first Flow     │
# │  and Crew.                                                                                                      │
# │    categories: tutorials, guides                                                                                │
# │    entities: ['CrewAI']                                                                                         │
# │    dates: []                                                                                                    │
# │    topics: ['Flow building', 'Crew tutorials']                                                                  │
# │  - (score=0.81) CrewAI is an open-source framework designed to orchestrate autonomous AI agents and build       │
# │  complex workflows.                                                                                             │
# │    categories: AI, Open-source, Frameworks, Workflows                                                           │
# │    entities: ['CrewAI']                                                                                         │
# │    dates: []                                                                                                    │
# │    topics: ['autonomous AI agents', 'workflows', 'orchestration']                                               │
# │  - (score=0.80) Autonomous Crews consist of teams of agents capable of intelligent decision-making and task     │
# │  execution.                                                                                                     │
# │    categories: autonomous systems, teams, intelligent decision-making                                           │
# │    entities: []                                                                                                 │
# │    dates: []                                                                                                    │
# │    topics: ['Autonomous Crews', 'decision-making', 'task execution']                                            │
# │  - (score=0.80) Crews enable autonomous collaboration where agents work together to solve complex problems.     │
# │    categories: collaboration, autonomy, problem_solving                                                         │
# │    entities: []                                                                                                 │
# │    dates: []                                                                                                    │
# │    topics: ['autonomous collaboration', 'agents', 'complex problems']                                           │
# │  - (score=0.80) CrewAI is designed to optimize costs by minimizing token usage and API calls.                   │
# │    categories: cost optimization, AI technology                                                                 │
# │    entities: ['CrewAI']                                                                                         │
# │    dates: []                                                                                                    │
# │    topics: ['cost optimization', 'minimizing token usage', 'API calls']                                         │
# │  - (score=0.80) Flows are structured, event-driven workflows in CrewAI that manage state and control            │
# │  execution.                                                                                                     │
# │    categories: Workflows, Event-driven Architecture                                                             │
# │    entities: ['CrewAI']                                                                                         │
# │    dates: []                                                                                                    │
# │    topics: ['structured workflows', 'event-driven workflows', 'state management', 'execution control']          │
# │  - (score=0.79) Crews consist of teams of autonomous agents within a Flow responsible for carrying out          │
# │  specific tasks.                                                                                                │
# │    categories: autonomous agents, teams, task management                                                        │
# │    entities: []                                                                                                 │
# │    dates: []                                                                                                    │
# │    topics: ['autonomous systems', 'crews', 'task execution']                                                    │
# │  - (score=0.78) The Flow triggers an event, manages state, and delegates complex tasks to a Crew.               │
# │    categories: events, task delegation, state management                                                        │
# │    entities: ['Flow', 'Crew']                                                                                   │
# │    dates: []                                                                                                    │
# │    topics: ['event management', 'workflow automation', 'task management']                                       │
# │  - (score=0.78) Agents within a Crew have specialized roles and capabilities tailored to fulfill parts of the   │
# │  task.                                                                                                          │
# │    categories: crew, roles, agents                                                                              │
# │    entities: []                                                                                                 │
# │    dates: []                                                                                                    │
# │    topics: ['crew dynamics', 'role specialization', 'task fulfillment']                                         │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Support Quality Analyst                                                                                 │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Hello Aman,                                                                                                    │
# │                                                                                                                 │
# │  Thank you for reaching out with your inquiry about CrewAI. I'm excited to provide you with a comprehensive     │
# │  overview to help you understand how CrewAI operates and how it can be leveraged for your data science          │
# │  projects.                                                                                                      │
# │                                                                                                                 │
# │  CrewAI is an open-source framework designed to orchestrate autonomous AI agents and build sophisticated        │
# │  workflows. It empowers developers to create production-ready multi-agent systems by combining the              │
# │  collaborative intelligence of Crews with the precise control of Flows.                                         │
# │                                                                                                                 │
# │  Here's a detailed explanation of the core concepts:                                                            │
# │                                                                                                                 │
# │  1. What is CrewAI?                                                                                             │
# │                                                                                                                 │
# │  CrewAI enables the construction of AI applications where multiple agents collaborate to accomplish complex     │
# │  tasks. This is achieved through two main components:                                                           │
# │                                                                                                                 │
# │  - Flows: Structured, event-driven workflows that manage state, execution logic, and data movement. Flows       │
# │  handle reliable, stateful workflows with complex logic, incorporating conditionals, loops, and branching to    │
# │  control the process flow efficiently.                                                                          │
# │                                                                                                                 │
# │  - Crews: Teams of autonomous agents operating within a Flow. Each Crew is responsible for specific, often      │
# │  complex, task execution delegated by the Flow. Agents in a Crew have specialized roles and capabilities,       │
# │  allowing them to collaborate like a human team to solve problems effectively.                                  │
# │                                                                                                                 │
# │  2. How Crews and Agents Work Together:                                                                         │
# │                                                                                                                 │
# │  - The Flow initiates an event or process.                                                                      │
# │  - It manages the workflow's state and determines next steps.                                                   │
# │  - Complex tasks are delegated to a Crew.                                                                       │
# │  - Agents within the Crew collaborate, role-playing their specialized functions to complete the task.           │
# │  - Results are returned to the Flow for further action.                                                         │
# │  - The Flow continues based on the Crew's output.                                                               │
# │                                                                                                                 │
# │  3. Benefits of Using Crews and Agents:                                                                         │
# │                                                                                                                 │
# │  - Autonomous collaboration among agents acting as a coordinated team.                                          │
# │  - Role specialization within agents ensuring task components are individually addressed.                       │
# │  - Enhanced problem-solving capacity for complex and creative tasks.                                            │
# │  - Flows oversee the entire process, while Crews handle intensive, specialized task execution within that       │
# │  process.                                                                                                       │
# │                                                                                                                 │
# │  4. Key Features and Advantages:                                                                                │
# │                                                                                                                 │
# │  - Production-grade Flows provide reliable and stateful workflows with intricate logic.                         │
# │  - Autonomous Crews capable of intelligent decision-making and execution.                                       │
# │  - Flexible integration with diverse APIs, databases, and local tools.                                          │
# │  - Enterprise-grade security, compliance, and scalability.                                                      │
# │  - Cost optimization by minimizing token usage and API calls.                                                   │
# │                                                                                                                 │
# │  5. Getting Started:                                                                                            │
# │                                                                                                                 │
# │  - Build your first Flow to create structured, event-driven workflows.                                          │
# │  - Set up your first Crew as a collaborative AI team.                                                           │
# │  - Install CrewAI and enhance your Crews with coding agent skills like Claude Code or Codex to accelerate       │
# │  development.                                                                                                   │
# │  - Utilize Crew steps within Flows for tasks that require autonomous agent collaboration.                       │
# │                                                                                                                 │
# │  For detailed tutorials and code examples, I highly recommend consulting the official CrewAI documentation,     │
# │  particularly the "Build Your First Flow" and "Build Your First Crew" guides available at                       │
# │  https://docs.crewai.com/introduction.                                                                          │
# │                                                                                                                 │
# │  Please feel free to reach out if you have further questions or need assistance with specific use cases. We're  │
# │  here to support you in making the most out of CrewAI for your projects.                                        │
# │                                                                                                                 │
# │  Best regards,                                                                                                  │
# │  [Your Name]                                                                                                    │
# │  Customer Care Specialist, CrewAI                                                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Evaluate the response prepared by the Customer Care Specialist for Unfold data science's inquiry.        │
# │  Ensure the reply meets the highest standards of accuracy, completeness, and clarity expected in customer       │
# │  service.                                                                                                       │
# │  Confirm that every aspect of the customer's question has been addressed in a friendly and approachable         │
# │  manner.                                                                                                        │
# │  Verify the inclusion of appropriate references and sources used to gather the information, ensuring the        │
# │  response is well-supported and leaves no loose ends.                                                           │
# │  Agent: Support Quality Analyst                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 53b62ccf-fc0d-4f2c-8022-014d428d5e5d                                                                       │
# │  Final Output: Hello Aman,                                                                                      │
# │                                                                                                                 │
# │  Thank you for reaching out with your inquiry about CrewAI. I'm excited to provide you with a comprehensive     │
# │  overview to help you understand how CrewAI operates and how it can be leveraged for your data science          │
# │  projects.                                                                                                      │
# │                                                                                                                 │
# │  CrewAI is an open-source framework designed to orchestrate autonomous AI agents and build sophisticated        │
# │  workflows. It empowers developers to create production-ready multi-agent systems by combining the              │
# │  collaborative intelligence of Crews with the precise control of Flows.                                         │
# │                                                                                                                 │
# │  Here's a detailed explanation of the core concepts:                                                            │
# │                                                                                                                 │
# │  1. What is CrewAI?                                                                                             │
# │                                                                                                                 │
# │  CrewAI enables the construction of AI applications where multiple agents collaborate to accomplish complex     │
# │  tasks. This is achieved through two main components:                                                           │
# │                                                                                                                 │
# │  - Flows: Structured, event-driven workflows that manage state, execution logic, and data movement. Flows       │
# │  handle reliable, stateful workflows with complex logic, incorporating conditionals, loops, and branching to    │
# │  control the process flow efficiently.                                                                          │
# │                                                                                                                 │
# │  - Crews: Teams of autonomous agents operating within a Flow. Each Crew is responsible for specific, often      │
# │  complex, task execution delegated by the Flow. Agents in a Crew have specialized roles and capabilities,       │
# │  allowing them to collaborate like a human team to solve problems effectively.                                  │
# │                                                                                                                 │
# │  2. How Crews and Agents Work Together:                                                                         │
# │                                                                                                                 │
# │  - The Flow initiates an event or process.                                                                      │
# │  - It manages the workflow's state and determines next steps.                                                   │
# │  - Complex tasks are delegated to a Crew.                                                                       │
# │  - Agents within the Crew collaborate, role-playing their specialized functions to complete the task.           │
# │  - Results are returned to the Flow for further action.                                                         │
# │  - The Flow continues based on the Crew's output.                                                               │
# │                                                                                                                 │
# │  3. Benefits of Using Crews and Agents:                                                                         │
# │                                                                                                                 │
# │  - Autonomous collaboration among agents acting as a coordinated team.                                          │
# │  - Role specialization within agents ensuring task components are individually addressed.                       │
# │  - Enhanced problem-solving capacity for complex and creative tasks.                                            │
# │  - Flows oversee the entire process, while Crews handle intensive, specialized task execution within that       │
# │  process.                                                                                                       │
# │                                                                                                                 │
# │  4. Key Features and Advantages:                                                                                │
# │                                                                                                                 │
# │  - Production-grade Flows provide reliable and stateful workflows with intricate logic.                         │
# │  - Autonomous Crews capable of intelligent decision-making and execution.                                       │
# │  - Flexible integration with diverse APIs, databases, and local tools.                                          │
# │  - Enterprise-grade security, compliance, and scalability.                                                      │
# │  - Cost optimization by minimizing token usage and API calls.                                                   │
# │                                                                                                                 │
# │  5. Getting Started:                                                                                            │
# │                                                                                                                 │
# │  - Build your first Flow to create structured, event-driven workflows.                                          │
# │  - Set up your first Crew as a collaborative AI team.                                                           │
# │  - Install CrewAI and enhance your Crews with coding agent skills like Claude Code or Codex to accelerate       │
# │  development.                                                                                                   │
# │  - Utilize Crew steps within Flows for tasks that require autonomous agent collaboration.                       │
# │                                                                                                                 │
# │  For detailed tutorials and code examples, I highly recommend consulting the official CrewAI documentation,     │
# │  particularly the "Build Your First Flow" and "Build Your First Crew" guides available at                       │
# │  https://docs.crewai.com/introduction.                                                                          │
# │                                                                                                                 │
# │  Please feel free to reach out if you have further questions or need assistance with specific use cases. We're  │
# │  here to support you in making the most out of CrewAI for your projects.                                        │
# │                                                                                                                 │
# │  Best regards,                                                                                                  │
# │  [Your Name]                                                                                                    │
# │  Customer Care Specialist, CrewAI                                                                               │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

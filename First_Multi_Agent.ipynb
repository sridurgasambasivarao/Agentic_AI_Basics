# %%
### My first agent is basically a chef. My second agent is basically a nutritionist. 
### So the job of both these agents together is to recommend some, recipe to the diabetic patient. I'm going to input a ingredient say chicken. 
### The job of the chef is to recommend five different items that can be made using chicken. The job of second agent is to analyze all these five foods 
### or recipes and tell me what is the best recipe for a diabetic patient.

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# %%
import crewai
from crewai import Agent, Task, Crew

# %%
# Load the .env file from local
import openai
from dotenv import load_dotenv
env_path = r'.env'
load_dotenv(env_path)
# Out:
# True

# %%
import os
os.environ["OPENAI_MODEL_NAME"] = 'gpt-4'

# %%
#1- Chef
chef = Agent(
    role="chef",
    goal="Give 5 different receipes using ingredients : {ingredients}",
    backstory="You're  a Chef who has experience on cooking delicious foods"
              "Your expertice lies in recommeding some new foods to the customers"
              "Please generate and give receipe of 5 different foods using this ingredients : {ingredients} "
              "describing stepwise process, time to cook, other ingredients needed and calorie count"
              "Your recipe will be critically analyzed by nutritutionist to recommend food for diabetes patients ",
	verbose=True
)

# %%
2# Nutritionist
nutritionist = Agent(
    role="nutritionist",
    goal="Critically analyze the recipe given by chef using these ingredients: {ingredients}",
    backstory="You're a nutritionist and have good knowledge on working with Diabetic patients "
              "There are recipe recommended by chef using these ingredients : {ingredients}. "
              "please critically analyze the recipe and suggest best food out of given 5 for Diabetic patients"
              "Also give reasons why you dont recommend other 4 receips and choose this one",
    verbose=True
)

# %%
cook = Task(
    description=(
        "1. Write receipe of 5 different foods using these ingredients  : {ingredients}.\n"
    ),
    expected_output="5 different receipes using {ingredients}"
                    "Stepwise guide to cook"
                    "List of all additional ingredients required for cooking"
                    "The expected taste of the food",
    agent=chef,
)

# %%
recommend = Task(
    description=(
        "1. Read the receipes provided by chef using {ingredients} \n"
        "2. critically analyze all receipes keeping in mind what should suit to diabetic patients.\n"
        "3. Suggest one best food out of all 5 receipes given by chef.\n"
        "4. Prove that other 4 receipes suggested by chef is not good for diabetic patients.\n"
        
    ),
    expected_output="A well-written critical pointwise analysis of all 5 recipes using {ingredients}"
                    "Suggest one receipe to diabetic patients based on your own knowledge and evidence "
                    "Reject all other 4 receipes with knowledge and evidence "
                    "Finally, give the stepwise receipe of what you selected and a nice message",
    agent=nutritionist,
)

# %%
crewaman = Crew(
    agents=[chef,nutritionist],
    tasks=[cook, recommend],
    verbose=True
)

# %%
result = crewaman.kickoff(inputs={"ingredients": "chicken"})
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 0c47d9a1-3922-4826-8e33-3f44a7fa0322                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: 1. Write receipe of 5 different foods using these ingredients  : chicken.                                │
# │                                                                                                                 │
# │  ID: 2d65eb42-1f2e-4eaf-b47f-85a95fa2285a                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: chef                                                                                                    │
# │                                                                                                                 │
# │  Task: 1. Write receipe of 5 different foods using these ingredients  : chicken.                                │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: chef                                                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  1. Grilled Herb Chicken:                                                                                       │
# │  Ingredients: 1lb chicken breast, 2 tbsp olive oil, 1 tsp dried basil, 1 tsp dried oregano, salt, pepper, and   │
# │  2 cloves garlic (minced).                                                                                      │
# │  Steps:                                                                                                         │
# │  - Preheat your grill on high.                                                                                  │
# │  - Mix olive oil, basil, oregano, minced garlic, salt, and pepper together.                                     │
# │  - Rub this mixture over the chicken breasts.                                                                   │
# │  - Grill the chicken on high for 5-7 minutes on each side, until cooked through.                                │
# │  Time to Cook: 20 minutes                                                                                       │
# │  Calories: Approximately 220 calories per serving.                                                              │
# │                                                                                                                 │
# │  2. Stir-Fried Chicken and Vegetables:                                                                          │
# │  Ingredients: 1lb chicken breast, 1 bell pepper, 1 onion, 2 cloves garlic (minced), 2 tbsp soy sauce            │
# │  (low-sodium), 2 tbsp olive oil, and pepper.                                                                    │
# │  Steps:                                                                                                         │
# │  - Chop the chicken, bell pepper, and onion into bite-sized pieces.                                             │
# │  - Heat the olive oil in a pan then add the minced garlic.                                                      │
# │  - Add the chicken and cook until browned.                                                                      │
# │  - Add the bell pepper, onion, soy sauce, and pepper, and stir-fry for another 5 minutes.                       │
# │  Time to Cook: 20 minutes                                                                                       │
# │  Calories: Approximately 210 calories per serving.                                                              │
# │                                                                                                                 │
# │  3. Lemon Garlic Roast Chicken:                                                                                 │
# │  Ingredients: 1lb chicken, 4 cloves garlic (minced), 2 lemons, 1 tbsp olive oil, salt, pepper, and 1 tsp dried  │
# │  rosemary.                                                                                                      │
# │  Steps:                                                                                                         │
# │  - Preheat your oven to 400°F (200°C).                                                                          │
# │  - In a bowl, mix the minced garlic, the juice of one lemon, olive oil, salt, pepper, and rosemary.             │
# │  - Rub this mixture all over the chicken and inside the cavity, then stuff the chicken with the juiced lemon    │
# │  and additional lemon cut into quarters.                                                                        │
# │  - Roast for approximately 50 minutes, or until the chicken is fully cooked.                                    │
# │  Time to Cook: 1 hour                                                                                           │
# │  Calories: Approximately 267 calories per serving.                                                              │
# │                                                                                                                 │
# │  4. Slow Cooker Chicken Tortilla Soup:                                                                          │
# │  Ingredients: 1lb chicken breast, 1 can diced tomatoes, 1 bell pepper, 1 onion, 2 cloves garlic (minced), 4     │
# │  cups chicken broth (low-sodium), 1 tsp chili powder, 1 tsp cumin, salt, pepper, and 2 tbsp olive oil.          │
# │  Steps:                                                                                                         │
# │  - Add all the ingredients to the slow cooker and cook on low for 6-8 hours.                                    │
# │  - Once cooked, shred the chicken using two forks and mix it back into the soup.                                │
# │  Time to Cook: 6-8 hours                                                                                        │
# │  Calories: Approximately 210 calories per serving.                                                              │
# │                                                                                                                 │
# │  5. Baked Parmesan Crusted Chicken:                                                                             │
# │  Ingredients: 1lb chicken breast, 1/2 cup Parmesan cheese (grated), 1 tbsp olive oil, 1 tsp dried basil, salt,  │
# │  and pepper.                                                                                                    │
# │  Steps:                                                                                                         │
# │  - Preheat your oven to 400°F (200°C).                                                                          │
# │  - Mix the Parmesan cheese, basil, salt, and pepper together.                                                   │
# │  - Brush the chicken breasts with olive oil and coat them with the Parmesan mixture.                            │
# │  - Bake for 20-25 minutes, or until the chicken is fully cooked.                                                │
# │  Time to Cook: 30 minutes                                                                                       │
# │  Calories: Approximately 253 calories per serving.                                                              │
# │                                                                                                                 │
# │  All these recipes have been designed keeping in mind the dietary requirements of diabetic patients, with the   │
# │  use of lean protein (chicken), low sodium, and beneficial herbs and spices. However, each individual may have  │
# │  unique dietary needs so it's crucial to consult with a healthcare provider or nutritionist.                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 1. Write receipe of 5 different foods using these ingredients  : chicken.                                │
# │                                                                                                                 │
# │  Agent: chef                                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: 1. Read the receipes provided by chef using chicken                                                      │
# │  2. critically analyze all receipes keeping in mind what should suit to diabetic patients.                      │
# │  3. Suggest one best food out of all 5 receipes given by chef.                                                  │
# │  4. Prove that other 4 receipes suggested by chef is not good for diabetic patients.                            │
# │                                                                                                                 │
# │  ID: 892c64dd-88f3-4d16-962b-bc98d0d9c6f8                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: nutritionist                                                                                            │
# │                                                                                                                 │
# │  Task: 1. Read the receipes provided by chef using chicken                                                      │
# │  2. critically analyze all receipes keeping in mind what should suit to diabetic patients.                      │
# │  3. Suggest one best food out of all 5 receipes given by chef.                                                  │
# │  4. Prove that other 4 receipes suggested by chef is not good for diabetic patients.                            │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: nutritionist                                                                                            │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Based on my analysis as a nutritionist, the most suitable recipe for individuals with diabetes from the given  │
# │  options is "Stir-Fried Chicken and Vegetables". This meal is a balanced combination of lean protein from the   │
# │  chicken and a good portion of non-starchy vegetables (bell pepper and onion). The use of low-sodium soy sauce  │
# │  keeps the salt content under control, which is important for people with diabetes as they often have high      │
# │  blood pressure. This recipe also seems to have the least amount of fat, making it a low-calorie choice.        │
# │                                                                                                                 │
# │  Now, let's discuss why I didn't choose the other recipes:                                                      │
# │                                                                                                                 │
# │  1. "Grilled Herb Chicken": Although it's a good source of protein, it lacks any source of fibrous              │
# │  carbohydrates. Neither fruits nor vegetables have been included which are important for maintaining blood      │
# │  sugar levels. Moreover, the use of salt might be a bit high for people with hypertension.                      │
# │                                                                                                                 │
# │  2. "Lemon Garlic Roast Chicken": While this recipe does incorporate beneficial ingredients, the quantity of    │
# │  olive oil and garlic may be in excess for some diabetics. Large amounts of olive oil can lead to weight gain,  │
# │  and garlic may potentially interfere with certain diabetic medications. Also, this recipe has the highest      │
# │  calorie count among the five.                                                                                  │
# │                                                                                                                 │
# │  3. "Slow Cooker Chicken Tortilla Soup": Even though this recipe includes vegetables, the canned diced          │
# │  tomatoes and chicken broth might contain added sugars or hidden sodium, which are not ideal for a diabetic     │
# │  diet.                                                                                                          │
# │                                                                                                                 │
# │  4. "Baked Parmesan Crusted Chicken": The usage of Parmesan cheese increases the fat content and overall        │
# │  calorie count of the dish. Excess calories and fat can lead to weight gain, which is not advisable for         │
# │  individuals with diabetes.                                                                                     │
# │                                                                                                                 │
# │  Here's the suggested recipe for "Stir-Fried Chicken and Vegetables":                                           │
# │                                                                                                                 │
# │  Ingredients: 1lb chicken breast, 1 bell pepper, 1 onion, 2 cloves garlic (minced), 2 tbsp soy sauce            │
# │  (low-sodium), 2 tbsp olive oil, and pepper.                                                                    │
# │  Steps:                                                                                                         │
# │  - Chop the chicken, bell pepper, and onion into bite-sized pieces.                                             │
# │  - Heat the olive oil in a pan then add the minced garlic.                                                      │
# │  - Add the chicken and cook until browned.                                                                      │
# │  - Add the bell pepper, onion, soy sauce, and pepper, and stir-fry for another 5 minutes.                       │
# │  Time to Cook: 20 minutes                                                                                       │
# │  Calories: Approximately 210 calories per serving.                                                              │
# │                                                                                                                 │
# │  Remember, exercise portion control when consuming this dish. Also, regular exercise along with a balanced      │
# │  diet will help you manage diabetes better. Finally, always consult your doctor or a dietitian before starting  │
# │  any new diet plan.                                                                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 1. Read the receipes provided by chef using chicken                                                      │
# │  2. critically analyze all receipes keeping in mind what should suit to diabetic patients.                      │
# │  3. Suggest one best food out of all 5 receipes given by chef.                                                  │
# │  4. Prove that other 4 receipes suggested by chef is not good for diabetic patients.                            │
# │                                                                                                                 │
# │  Agent: nutritionist                                                                                            │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 0c47d9a1-3922-4826-8e33-3f44a7fa0322                                                                       │
# │  Final Output: Based on my analysis as a nutritionist, the most suitable recipe for individuals with diabetes   │
# │  from the given options is "Stir-Fried Chicken and Vegetables". This meal is a balanced combination of lean     │
# │  protein from the chicken and a good portion of non-starchy vegetables (bell pepper and onion). The use of      │
# │  low-sodium soy sauce keeps the salt content under control, which is important for people with diabetes as      │
# │  they often have high blood pressure. This recipe also seems to have the least amount of fat, making it a       │
# │  low-calorie choice.                                                                                            │
# │                                                                                                                 │
# │  Now, let's discuss why I didn't choose the other recipes:                                                      │
# │                                                                                                                 │
# │  1. "Grilled Herb Chicken": Although it's a good source of protein, it lacks any source of fibrous              │
# │  carbohydrates. Neither fruits nor vegetables have been included which are important for maintaining blood      │
# │  sugar levels. Moreover, the use of salt might be a bit high for people with hypertension.                      │
# │                                                                                                                 │
# │  2. "Lemon Garlic Roast Chicken": While this recipe does incorporate beneficial ingredients, the quantity of    │
# │  olive oil and garlic may be in excess for some diabetics. Large amounts of olive oil can lead to weight gain,  │
# │  and garlic may potentially interfere with certain diabetic medications. Also, this recipe has the highest      │
# │  calorie count among the five.                                                                                  │
# │                                                                                                                 │
# │  3. "Slow Cooker Chicken Tortilla Soup": Even though this recipe includes vegetables, the canned diced          │
# │  tomatoes and chicken broth might contain added sugars or hidden sodium, which are not ideal for a diabetic     │
# │  diet.                                                                                                          │
# │                                                                                                                 │
# │  4. "Baked Parmesan Crusted Chicken": The usage of Parmesan cheese increases the fat content and overall        │
# │  calorie count of the dish. Excess calories and fat can lead to weight gain, which is not advisable for         │
# │  individuals with diabetes.                                                                                     │
# │                                                                                                                 │
# │  Here's the suggested recipe for "Stir-Fried Chicken and Vegetables":                                           │
# │                                                                                                                 │
# │  Ingredients: 1lb chicken breast, 1 bell pepper, 1 onion, 2 cloves garlic (minced), 2 tbsp soy sauce            │
# │  (low-sodium), 2 tbsp olive oil, and pepper.                                                                    │
# │  Steps:                                                                                                         │
# │  - Chop the chicken, bell pepper, and onion into bite-sized pieces.                                             │
# │  - Heat the olive oil in a pan then add the minced garlic.                                                      │
# │  - Add the chicken and cook until browned.                                                                      │
# │  - Add the bell pepper, onion, soy sauce, and pepper, and stir-fry for another 5 minutes.                       │
# │  Time to Cook: 20 minutes                                                                                       │
# │  Calories: Approximately 210 calories per serving.                                                              │
# │                                                                                                                 │
# │  Remember, exercise portion control when consuming this dish. Also, regular exercise along with a balanced      │
# │  diet will help you manage diabetes better. Finally, always consult your doctor or a dietitian before starting  │
# │  any new diet plan.                                                                                             │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ┌───────────────────────── Tracing Preference Saved ──────────────────────────┐
# │                                                                             │
# │  Info: Tracing has been disabled.                                           │
# │                                                                             │
# │  Your preference has been saved. Future Crew/Flow executions will not       │
# │  collect traces.                                                            │
# │                                                                             │
# │  To enable tracing later, do any one of these:                              │
# │  • Set tracing=True in your Crew/Flow code                                  │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file              │
# │  • Run: crewai traces enable                                                │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘

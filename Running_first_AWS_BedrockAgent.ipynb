# %% [markdown]
# ### Build our first agent in Bedrock and call it from python

# %%
import boto3

# %%
import json
import uuid
session_id = str(uuid.uuid4())

# %%
ROLE_ARN = "arn:aws:iam::973370773112:role/service-role/AmazonBedrockExecutionRoleForAgents_EVBAADVDDW"
REGION = 'us-east-2'

# %%
sts_client = boto3.client('sts')

# %%
assumed_role_object = sts_client.assume_role(
    RoleArn=ROLE_ARN, RoleSessionName='MySession'
)
credentials = assumed_role_object['Credentials']

# %%
# Create a new client using the assumed role credentials
bedrock_agent_runtime = boto3.client(
    'bedrock-agent-runtime',  # Correct: Use 'bedrock-agent-runtime'
    aws_access_key_id=credentials['AccessKeyId'],
    aws_secret_access_key=credentials['SecretAccessKey'],
    aws_session_token=credentials['SessionToken'],
    region_name=REGION
)

# %%
# Input for the agent
input_text = "Hi I need help with choosing a course, can you help"

# %%
try:
    invoke_agent_response = bedrock_agent_runtime.invoke_agent(
        agentId='R8FTBVXDSD', agentAliasId='9UBNF4NRXP', inputText=input_text, sessionId=session_id
    )
    event_stream = invoke_agent_response["completion"]
    
    for event in event_stream:
        print(event['chunk']['bytes'].decode())

except Exception as e:
    print(f"Error: {e}")
# Out:
# I need to ask the User for their years of professional experience and a specific data science topic or courses they're interested in.
